# %% [markdown]
# <a href="https://colab.research.google.com/github/kherin/daily/blob/master/Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame([{"first": "foo", "last": "bar", "title": "Mr"}, {"first":"fizz", "last": "fuzz", "title": "Mrs"}])

# %%
df.head()
# Out:
#   first  last title
# 0   foo   bar    Mr
# 1  fizz  fuzz   Mrs

# %% [markdown]
# ## Learning about `melt` method

# %%
df.melt(id_vars=["first"])
# Out:
#   first variable value
# 0   foo     last   bar
# 1  fizz     last  fuzz
# 2   foo    title    Mr
# 3  fizz    title   Mrs
